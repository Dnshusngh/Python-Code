# %%
import pandas as pd

data = {"age": [1, 2, 3, 4, 5, 6, 7, 8, 9],
    "cher": ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']}

df = pd.DataFrame(data)
print(df)
# Out:
#    age cher
# 0    1    a
# 1    2    b
# 2    3    c
# 3    4    d
# 4    5    e
# 5    6    f
# 6    7    g
# 7    8    h
# 8    9    i

# %%
import pandas as pd
import numpy as np

# Creating a DataFrame from a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, np.nan, 22],
    'City': ['New York', 'San Francisco', 'Los Angeles', 'New York'],
    'Salary': [50000, 60000, 45000, np.nan]
}

df = pd.DataFrame(data)

# Displaying the DataFrame
print("Original DataFrame:")
print(df)

# Checking for missing values
print("\nMissing Values:")
print(df.isnull())

# Filling missing values
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Salary'].fillna(0, inplace=True)

# Dropping duplicate rows
df.drop_duplicates(inplace=True)

# Displaying the cleaned DataFrame
print("\nCleaned DataFrame:")
print(df)

# Reading data from a CSV file
# Assuming the CSV file 'example.csv' contains columns: Name, Age, City, Salary
csv_df = pd.read_csv('example.csv')

# Displaying the CSV DataFrame
print("\nDataFrame from CSV:")
print(csv_df)
# Out:
#    age cher
# 0    1    a
# 1    2    b
# 2    3    c
# 3    4    d
# 4    5    e
# 5    6    f
# 6    7    g
# 7    8    h
# 8    9    i

# %%
import pandas as pd

df = pd.read_csv('C:\\Users\\Reliance Digital\\Desktop\\DBMS\\ign.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
# 5           5         Good                          Total War Battles: Shogun
# 6           6        Awful                                Double Dragon: Neon
# 7           7      Amazing                                       Guild Wars 2
# 8           8        Awful                                Double Dragon: Neon
# 9           9         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0 score_phrase                                    title  \
# 18620       18620         Good                Tokyo Mirage Sessions #FE
# 18621       18621      Amazing        LEGO Star Wars: The Force Awakens
# 18622       18622     Mediocre  Star Ocean: Integrity and Faithlessness
# 18623       18623  Masterpiece                                   Inside
# 18624       18624  Masterpiece                                   Inside
#
#                                                      url       platform  \
# 18620  /games/fire-emblem-x-shin-megami-tensei/wii-u-...          Wii U
# 18621  /games/lego-star-wars-the-force-awakens/ps4-20...  PlayStation 4
# 18622                   /games/star-ocean-5/ps4-20035681  PlayStation 4
# 18623             /games/inside-playdead/xbox-one-121435       Xbox One
# 18624                 /games/inside-playdead/pc-20055740             PC
#
#        score              genre editors_choice  release_year  release_month  \
# ...

# %%
missing = df.isnull().sum

# %%
print(missing)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of        Unnamed: 0  score_phrase  title    url  platform  score  genre  \
# 0           False         False  False  False     False  False  False
# 1           False         False  False  False     False  False  False
# 2           False         False  False  False     False  False  False
# 3           False         False  False  False     False  False  False
# 4           False         False  False  False     False  False  False
# ...           ...           ...    ...    ...       ...    ...    ...
# 18620       False         False  False  False     False  False  False
# 18621       False         False  False  False     False  False  False
# 18622       False         False  False  False     False  False  False
# 18623       False         False  False  False     False  False  False
# 18624       False         False  False  False     False  False  False
#
#        editors_choice  release_year  release_month  release_day
# ...

# %%
df["title"].isnull().sum()
# Out:
# 0

# %%
df["genre"].isnull().sum()
# Out:
# 36

# %%
df["release_year"].isnull().sum()
# Out:
# 0

# %%
df[:25].tail(15)
# Out:
#     Unnamed: 0 score_phrase                                title  \
# 10          10         Good              Tekken Tag Tournament 2
# 11          11         Good              Tekken Tag Tournament 2
# 12          12         Good                           Wild Blood
# 13          13      Amazing                    Mark of the Ninja
# 14          14      Amazing                    Mark of the Ninja
# 15          15         Okay      Home: A Unique Horror Adventure
# 16          16         Okay      Home: A Unique Horror Adventure
# 17          17        Great                  Avengers Initiative
# 18          18     Mediocre                 Way of the Samurai 4
# 19          19         Good          JoJo's Bizarre Adventure HD
# 20          20         Good          JoJo's Bizarre Adventure HD
# 21          21         Good             Mass Effect 3: Leviathan
# 22          22         Good             Mass Effect 3: Leviathan
# ...

# %%
ffill_imp = df.fillna(method='ffill')
print(ffill_imp)
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# ...           ...          ...
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# ...                                                  ...
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# ...

# %%
ffill_imp = df.fillna(method='ffill')
print(ffill_imp)

# %%
ffill_imp = df.fillna(method='ffill')
print

# %%
import pandas as pd

df = pd.read_csv('G:\Csv\DATABASE SQL .csv')

# %%
df.head(10)
# Out:
#    Student_id  First_name  Last_name         DOB   Age       Phone no  \
# 0      1001.0        John        Doe  15-05-1998  25.0   123-456-7890
# 1      1002.0        Jane      Smith  23-08-1999  24.0   987-654-3210
# 2      1003.0        Mike    Johnson  10-03-2000  23.0   555-555-5555
# 3      1004.0       Emily      Davis  02-11-1997  26.0   111-222-3333
# 4      1005.0       David        Lee  18-07-2002  21.0   999-888-7777
# 5      1006.0       Sarah      Brown  14-02-1995  28.0   777-888-9999
# 6      1007.0      Daniel     Wilson  30-09-2001  22.0   222-333-4444
# 7      1008.0      Olivia     Garcia  05-12-1996  27.0   444-333-2222
# 8      1009.0     Matthew   Martinez  29-04-1999  24.0   333-444-5555
# 9      1010.0        Emma   Anderson  12-01-2003  20.0   555-444-3333
#
#              City   Pincode  Hostel_id          Hostel_name Hostel_room_type  \
# 0        New York   10001.0     2001.0             Cozy Inn               AC
# ...

# %%
from sklearn.impute import KNNImputer
df_knn=df['Pincode']. to_frame('Pincode')
knn_imputer = KNNImputer(n_neighbors=5, weights = 'uniform', metric='nan_euclidean')
df_knn_imputed = pd.DataFrame(knn_impute.fit_transform(df_knn),columns=df_knn.columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pincode'
#
# The above exception was the direct cause of the following exception:
#
# ...
